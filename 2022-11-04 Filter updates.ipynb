# %%
import pandas as pd
import numpy as np
import nltk
import re
import geonamescache
import seaborn as sns

# %%
df = pd.read_csv('ndc.csv')
df = df.dropna()
print(df)
# Out:
#                               name
# 0                       Row Labels
# 1                SPIRONOLACTONE %
# 2        -L'Oreal USA Products Inc
# 3                 .Cardinal Health
# 4     .Church & Dwight Canada Corp
# ...                            ...
# 7022                        ZYGONE
# 7023    Zyla Life Sciences US Inc.
# 7024                        #NAME?
# 7025                       (blank)
# 7026                   Grand Total
#
# [7027 rows x 1 columns]

# %% [markdown]
# # Make everything lower case

# %%
df['lower_name'] = df['name'].str.lower()
df
# Out:
#                               name                    lower_name
# 0                       Row Labels                    row labels
# 1                SPIRONOLACTONE %              spironolactone %
# 2        -L'Oreal USA Products Inc     -l'oreal usa products inc
# 3                 .Cardinal Health              .cardinal health
# 4     .Church & Dwight Canada Corp  .church & dwight canada corp
# ...                            ...                           ...
# 7022                        ZYGONE                        zygone
# 7023    Zyla Life Sciences US Inc.    zyla life sciences us inc.
# 7024                        #NAME?                        #name?
# 7025                       (blank)                       (blank)
# 7026                   Grand Total                   grand total
#
# [7027 rows x 2 columns]

# %% [markdown]
# # Remove all non-alphanumeric characters except white spaces

# %%
df['filter_alpha_num'] = df['lower_name'].apply(lambda x: re.sub(r'[^a-zA-Z\d\s:]', '', x))
df
# Out:
#                               name                    lower_name  \
# 0                       Row Labels                    row labels
# 1                SPIRONOLACTONE %              spironolactone %
# 2        -L'Oreal USA Products Inc     -l'oreal usa products inc
# 3                 .Cardinal Health              .cardinal health
# 4     .Church & Dwight Canada Corp  .church & dwight canada corp
# ...                            ...                           ...
# 7022                        ZYGONE                        zygone
# 7023    Zyla Life Sciences US Inc.    zyla life sciences us inc.
# 7024                        #NAME?                        #name?
# 7025                       (blank)                       (blank)
# 7026                   Grand Total                   grand total
#
#                 filter_alpha_num
# 0                     row labels
# 1               spironolactone
# 2        loreal usa products inc
# 3                cardinal health
# 4     church  dwight canada corp
# ...                          ...
# 7022                      zygone
# 7023   zyla life sciences us inc
# 7024                        name
# 7025                       blank
# 7026                 grand total
#
# [7027 rows x 3 columns]

# %% [markdown]
# # Remove common company abbreviations

# %%
company_abbrev = {
    "labs",
    "bio",
    "biotech",
    "laboratories",
    "ventures",
    "solutions",
    "sciences",
    "partners",
    "holdings",
    "son",
    "co",
    "corp",
    "corporation",
    "inc",
    "incorporated",
    "brothers",
    "tech",
    "foods",
    "books",
    "industrial",
    "innovations",
    "bureau",
    "prestige",
    "worldwide",
    "international",
    "direct",
    "online",
    "properties",
    "pharm",
    "pharms",
    "pharma",
    "usa",
    "development",
    "technologies",
    "consulting",
    "works",
    "unlimited",
    "specialties",
    "scintific",
    "digital",
    "brands",
    "logistics",
    "llc",
    "ltd",
    "companies",
    "company",
    "creative",
    "productions",
    "prod",
}

def filter_company_abbrev(company_name):
    return " ".join([v for v in nltk.word_tokenize(company_name) if not v in company_abbrev])

df['filter_comp_abbrev'] = df['filter_alpha_num'].map(filter_company_abbrev)
df
# Out:
#                               name                    lower_name  \
# 0                       Row Labels                    row labels
# 1                SPIRONOLACTONE %              spironolactone %
# 2        -L'Oreal USA Products Inc     -l'oreal usa products inc
# 3                 .Cardinal Health              .cardinal health
# 4     .Church & Dwight Canada Corp  .church & dwight canada corp
# ...                            ...                           ...
# 7022                        ZYGONE                        zygone
# 7023    Zyla Life Sciences US Inc.    zyla life sciences us inc.
# 7024                        #NAME?                        #name?
# 7025                       (blank)                       (blank)
# 7026                   Grand Total                   grand total
#
#                 filter_alpha_num    filter_comp_abbrev
# 0                     row labels            row labels
# 1               spironolactone          spironolactone
# 2        loreal usa products inc       loreal products
# 3                cardinal health       cardinal health
# 4     church  dwight canada corp  church dwight canada
# ...                          ...                   ...
# 7022                      zygone                zygone
# 7023   zyla life sciences us inc          zyla life us
# 7024                        name                  name
# 7025                       blank                 blank
# 7026                 grand total           grand total
#
# [7027 rows x 4 columns]

# %% [markdown]
# # Remove countries and cities information

# %%
gc = geonamescache.GeonamesCache()

continents = gc.get_continents()
# print(continents)
continents = [continents[key]['name'].lower() for key in continents]

countries = gc.get_countries()
countries = [countries[key]['name'].lower() for key in countries]

cities = gc.get_cities()
cities = [cities[key]['name'].lower() for key in cities]

continents.extend(countries)
continents.extend(cities)
locations = continents

# print('usa' in locations) # False
# print('us' in locations) # False
# print('united states' in locations) # True
# Adding some abbreviations
locations.extend(['usa', 'us'])

locations = set(locations)

# %%
def filter_locations(company_name):
    return " ".join([v for v in nltk.word_tokenize(company_name) if not v in locations])

print(filter_locations('loreal usa products inc'))

df['filter_loc'] = df['filter_comp_abbrev'].apply(lambda x: filter_locations(x))
df
# Out:
# loreal products inc
#                               name                    lower_name  \
# 0                       Row Labels                    row labels
# 1                SPIRONOLACTONE %              spironolactone %
# 2        -L'Oreal USA Products Inc     -l'oreal usa products inc
# 3                 .Cardinal Health              .cardinal health
# 4     .Church & Dwight Canada Corp  .church & dwight canada corp
# ...                            ...                           ...
# 7022                        ZYGONE                        zygone
# 7023    Zyla Life Sciences US Inc.    zyla life sciences us inc.
# 7024                        #NAME?                        #name?
# 7025                       (blank)                       (blank)
# 7026                   Grand Total                   grand total
#
#                 filter_alpha_num    filter_comp_abbrev       filter_loc
# 0                     row labels            row labels       row labels
# 1               spironolactone          spironolactone   spironolactone
# 2        loreal usa products inc       loreal products  loreal products
# 3                cardinal health       cardinal health  cardinal health
# 4     church  dwight canada corp  church dwight canada    church dwight
# ...                          ...                   ...              ...
# 7022                      zygone                zygone           zygone
# 7023   zyla life sciences us inc          zyla life us        zyla life
# 7024                        name                  name             name
# 7025                       blank                 blank            blank
# 7026                 grand total           grand total      grand total
#
# [7027 rows x 5 columns]

# %% [markdown]
# # Remove all common dictionary terms (and their plural forms)

# %%
from nltk.corpus import words

dictionary_words = words.words()
dictionary_words = set([v for v in dictionary_words if len(v) > 1])

p = nltk.PorterStemmer()

# %%
# def filter_common_words(company_name):
#     # print([v for v in nltk.word_tokenize(company_name) if v in dictionary_words])
#     return " ".join([v for v in nltk.word_tokenize(company_name) if not p.stem(v) in dictionary_words])

# df['filter_common'] = df['filter_loc'].apply(lambda x: filter_common_words(x))
# df

# %% [markdown]
# # Select the shortest string among the columns

# %%
def get_shortest(*args):
    return min([v for v in args if len(v) > 0], key=len)
    
df['cleaned'] = df.apply(lambda x: get_shortest(x['lower_name'], x['filter_alpha_num'], x['filter_loc'], x['filter_comp_abbrev']), axis=1)

# %%
df.sample(50)
# Out:
#                                                    name  \
# 143                       Advanced Healthcare Solutions
# 2109                                      e Pharma, LLC
# 2190                                        EltaMD, Inc
# 6408                    Tri Lakes Home Medical Eq. Inc.
# 6380                            Topical BioMedics, Inc.
# 6280  The University of Utah DBA Cyclotron Radiochem...
# 4255                         Mylan Pharmaceuticals Inc.
# 3106                          Hyatt Life Sciences, Inc.
# 472                                                ANDA
# 1458                               Chain Drug Marketing
# 2547                       Geiss, Destin and Dunn, Inc.
# 1680                                   Costory Co., Ltd
# 1269                     BUZZ PRODUCTS (HK) CO. LIMITED
# 6502                Unichem Pharmaceuticals (USA), Inc.
# 6681                                Vivier Pharma, Inc.
# 190                                  Ahold U.S.A., Inc,
# 1247                                 Budsworth Labs LLC
# 163                                     Aetna Felt Corp
# 3921                         MAX HUBER RESEARCH LAB INC
# 3680                             Lead Chemical Co. Ltd.
# 3029                Homeolab International (Canada) inc
# 1736                              CURRENT SOLUTIONS LLC
# 3760                          Lippmann Enterprises, LLC
# 6023                           Sunburst Chemicals, Inc.
# 5718                  shenzhen Lantern Science Co. Ltd.
# 4866                   Patient Focused Tele-Health, LLC
# 4268                                   Nanovita One LLC
# 4003                   Medical Purchasin Solutions, LLC
# 965                         Belcher Pharmaceuticals,LLC
# 1045                        BioActive Nutritional Inc .
# 6970                     Yves Rocher North America Inc.
# 2050                        Dr.Reddy's Laboratories Inc
# 123                                  Adamas Pharma, LLC
# 2467                                              Freds
# 999                                          BestCo Inc
# 3357                                   JAR Laboratories
# 4655                            NYC Medical Practice PC
# 2373                                        FFREDS, INC
# 1366                                            CareOne
# 3622                            LABORATORIOS GRIFOLS SA
# 4557                        Nordic Clinical Center, LLC
# 3212                                        Inopak. Ltd
# 628                                                ANDA
# 1449                         Chain Drug Consortium, LLC
# 2832                              Hamilton Therapeutics
# 2944                                HELLO SKIN Co.,Ltd.
# 171                                       Afflink, Inc.
# 4060                                Meijer Distribution
# 429                         amsino healthcare (USA) inc
# 3066         Hub's Home Oxygen & Medical Supplies, Inc.
#
#                                              lower_name  \
# 143                       advanced healthcare solutions
# 2109                                      e pharma, llc
# 2190                                        eltamd, inc
# 6408                    tri lakes home medical eq. inc.
# 6380                            topical biomedics, inc.
# 6280  the university of utah dba cyclotron radiochem...
# 4255                         mylan pharmaceuticals inc.
# 3106                          hyatt life sciences, inc.
# 472                                                anda
# 1458                               chain drug marketing
# 2547                       geiss, destin and dunn, inc.
# 1680                                   costory co., ltd
# 1269                     buzz products (hk) co. limited
# 6502                unichem pharmaceuticals (usa), inc.
# 6681                                vivier pharma, inc.
# 190                                  ahold u.s.a., inc,
# 1247                                 budsworth labs llc
# 163                                     aetna felt corp
# 3921                         max huber research lab inc
# 3680                             lead chemical co. ltd.
# 3029                homeolab international (canada) inc
# 1736                              current solutions llc
# 3760                          lippmann enterprises, llc
# 6023                           sunburst chemicals, inc.
# 5718                  shenzhen lantern science co. ltd.
# 4866                   patient focused tele-health, llc
# 4268                                   nanovita one llc
# 4003                   medical purchasin solutions, llc
# 965                         belcher pharmaceuticals,llc
# 1045                        bioactive nutritional inc .
# 6970                     yves rocher north america inc.
# 2050                        dr.reddy's laboratories inc
# 123                                  adamas pharma, llc
# 2467                                              freds
# 999                                          bestco inc
# 3357                                   jar laboratories
# 4655                            nyc medical practice pc
# 2373                                        ffreds, inc
# 1366                                            careone
# 3622                            laboratorios grifols sa
# 4557                        nordic clinical center, llc
# 3212                                        inopak. ltd
# 628                                                anda
# 1449                         chain drug consortium, llc
# 2832                              hamilton therapeutics
# 2944                                hello skin co.,ltd.
# 171                                       afflink, inc.
# 4060                                meijer distribution
# 429                         amsino healthcare (usa) inc
# 3066         hub's home oxygen & medical supplies, inc.
#
#                                        filter_alpha_num  \
# 143                       advanced healthcare solutions
# 2109                                       e pharma llc
# 2190                                         eltamd inc
# 6408                      tri lakes home medical eq inc
# 6380                              topical biomedics inc
# 6280  the university of utah dba cyclotron radiochem...
# 4255                          mylan pharmaceuticals inc
# 3106                            hyatt life sciences inc
# 472                                                anda
# 1458                               chain drug marketing
# 2547                          geiss destin and dunn inc
# 1680                                     costory co ltd
# 1269                        buzz products hk co limited
# 6502                    unichem pharmaceuticals usa inc
# 6681                                  vivier pharma inc
# 190                                       ahold usa inc
# 1247                                 budsworth labs llc
# 163                                     aetna felt corp
# 3921                         max huber research lab inc
# 3680                               lead chemical co ltd
# 3029                  homeolab international canada inc
# 1736                              current solutions llc
# 3760                           lippmann enterprises llc
# 6023                             sunburst chemicals inc
# 5718                    shenzhen lantern science co ltd
# 4866                     patient focused telehealth llc
# 4268                                   nanovita one llc
# 4003                    medical purchasin solutions llc
# 965                          belcher pharmaceuticalsllc
# 1045                         bioactive nutritional inc
# 6970                      yves rocher north america inc
# 2050                          drreddys laboratories inc
# 123                                   adamas pharma llc
# 2467                                              freds
# 999                                          bestco inc
# 3357                                   jar laboratories
# 4655                            nyc medical practice pc
# 2373                                         ffreds inc
# 1366                                            careone
# 3622                            laboratorios grifols sa
# 4557                         nordic clinical center llc
# 3212                                         inopak ltd
# 628                                                anda
# 1449                          chain drug consortium llc
# 2832                              hamilton therapeutics
# 2944                                   hello skin coltd
# 171                                         afflink inc
# 4060                                meijer distribution
# 429                           amsino healthcare usa inc
# 3066             hubs home oxygen  medical supplies inc
#
#                                      filter_comp_abbrev  \
# 143                                 advanced healthcare
# 2109                                                  e
# 2190                                             eltamd
# 6408                          tri lakes home medical eq
# 6380                                  topical biomedics
# 6280  the university of utah dba cyclotron radiochem...
# 4255                              mylan pharmaceuticals
# 3106                                         hyatt life
# 472                                                anda
# 1458                               chain drug marketing
# 2547                              geiss destin and dunn
# 1680                                            costory
# 1269                           buzz products hk limited
# 6502                            unichem pharmaceuticals
# 6681                                             vivier
# 190                                               ahold
# 1247                                          budsworth
# 163                                          aetna felt
# 3921                             max huber research lab
# 3680                                      lead chemical
# 3029                                    homeolab canada
# 1736                                            current
# 3760                               lippmann enterprises
# 6023                                 sunburst chemicals
# 5718                           shenzhen lantern science
# 4866                         patient focused telehealth
# 4268                                       nanovita one
# 4003                                  medical purchasin
# 965                          belcher pharmaceuticalsllc
# 1045                              bioactive nutritional
# 6970                          yves rocher north america
# 2050                                           drreddys
# 123                                              adamas
# 2467                                              freds
# 999                                              bestco
# 3357                                                jar
# 4655                            nyc medical practice pc
# 2373                                             ffreds
# 1366                                            careone
# 3622                            laboratorios grifols sa
# 4557                             nordic clinical center
# 3212                                             inopak
# 628                                                anda
# 1449                              chain drug consortium
# 2832                              hamilton therapeutics
# 2944                                   hello skin coltd
# 171                                             afflink
# 4060                                meijer distribution
# 429                                   amsino healthcare
# 3066                  hubs home oxygen medical supplies
#
#                                      filter_loc  \
# 143                         advanced healthcare
# 2109                                          e
# 2190                                     eltamd
# 6408                  tri lakes home medical eq
# 6380                          topical biomedics
# 6280  the utah dba cyclotron radiochemistry lab
# 4255                      mylan pharmaceuticals
# 3106                                 hyatt life
# 472
# 1458                       chain drug marketing
# 2547                      geiss destin and dunn
# 1680                                    costory
# 1269                   buzz products hk limited
# 6502                    unichem pharmaceuticals
# 6681                                     vivier
# 190                                       ahold
# 1247                                  budsworth
# 163                                  aetna felt
# 3921                     max huber research lab
# 3680                              lead chemical
# 3029                                   homeolab
# 1736                                    current
# 3760                       lippmann enterprises
# 6023                         sunburst chemicals
# 5718                            lantern science
# 4866                 patient focused telehealth
# 4268                               nanovita one
# 4003                          medical purchasin
# 965                  belcher pharmaceuticalsllc
# 1045                      bioactive nutritional
# 6970                  yves rocher north america
# 2050                                   drreddys
# 123                                      adamas
# 2467                                      freds
# 999                                      bestco
# 3357                                        jar
# 4655                    nyc medical practice pc
# 2373                                     ffreds
# 1366                                    careone
# 3622                    laboratorios grifols sa
# 4557                     nordic clinical center
# 3212                                     inopak
# 628
# 1449                      chain drug consortium
# 2832                               therapeutics
# 2944                           hello skin coltd
# 171                                     afflink
# 4060                        meijer distribution
# 429                           amsino healthcare
# 3066          hubs home oxygen medical supplies
#
#                                         cleaned
# 143                         advanced healthcare
# 2109                                          e
# 2190                                     eltamd
# 6408                  tri lakes home medical eq
# 6380                          topical biomedics
# 6280  the utah dba cyclotron radiochemistry lab
# 4255                      mylan pharmaceuticals
# 3106                                 hyatt life
# 472                                        anda
# 1458                       chain drug marketing
# 2547                      geiss destin and dunn
# 1680                                    costory
# 1269                   buzz products hk limited
# 6502                    unichem pharmaceuticals
# 6681                                     vivier
# 190                                       ahold
# 1247                                  budsworth
# 163                                  aetna felt
# 3921                     max huber research lab
# 3680                              lead chemical
# 3029                                   homeolab
# 1736                                    current
# 3760                       lippmann enterprises
# 6023                         sunburst chemicals
# 5718                            lantern science
# 4866                 patient focused telehealth
# 4268                               nanovita one
# 4003                          medical purchasin
# 965                  belcher pharmaceuticalsllc
# 1045                      bioactive nutritional
# 6970                  yves rocher north america
# 2050                                   drreddys
# 123                                      adamas
# 2467                                      freds
# 999                                      bestco
# 3357                                        jar
# 4655                    nyc medical practice pc
# 2373                                     ffreds
# 1366                                    careone
# 3622                    laboratorios grifols sa
# 4557                     nordic clinical center
# 3212                                     inopak
# 628                                        anda
# 1449                      chain drug consortium
# 2832                               therapeutics
# 2944                           hello skin coltd
# 171                                     afflink
# 4060                        meijer distribution
# 429                           amsino healthcare
# 3066          hubs home oxygen medical supplies
